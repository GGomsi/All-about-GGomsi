# %%
# !pip install pyautogui
# Out:
# Requirement already satisfied: pyautogui in c:\users\user\anaconda3\lib\site-packages (0.9.53)
# Requirement already satisfied: pygetwindow>=0.0.5 in c:\users\user\anaconda3\lib\site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: mouseinfo in c:\users\user\anaconda3\lib\site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: pymsgbox in c:\users\user\anaconda3\lib\site-packages (from pyautogui) (1.0.9)
# Requirement already satisfied: PyTweening>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from pyautogui) (1.0.4)
# Requirement already satisfied: pyscreeze>=0.1.21 in c:\users\user\anaconda3\lib\site-packages (from pyautogui) (0.1.28)
# Requirement already satisfied: pyrect in c:\users\user\anaconda3\lib\site-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: pyperclip in c:\users\user\anaconda3\lib\site-packages (from mouseinfo->pyautogui) (1.8.2)

# %%
# !pip install pyperclip
# Out:
# Requirement already satisfied: pyperclip in c:\users\user\anaconda3\lib\site-packages (1.8.2)

# %%
# !pip install schedule
# Out:
# Collecting schedule
#   Downloading schedule-1.1.0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: schedule
# Successfully installed schedule-1.1.0

# %%
import pyautogui
import pyperclip
import time
import os

# 경로를 지정한 파일의 실행경로로 이동, 그리고 절대경로로 지정한다.
os.chdir(os.path.dirname(os.path.abspath('autokakao.ipynb')))

# 
picPosition = pyautogui.locateOnScreen('1.png')
print(picPosition)

if picPosition is None:
    picPosition = pyautogui.locateOnScreen('2.png')
    print(picPosition)

if picPosition is None:
    picPosition = pyautogui.locateOnScreen('3.png')
    print(picPosition)

clickPosition = pyautogui.center(picPosition)
pyautogui.doubleClick(clickPosition)

pyperclip.copy("테스트용 해위")
pyautogui.hotkey("ctrl", "v")
time.sleep(1.0)

pyautogui.write(["enter"])
time.sleep(1.0)

pyautogui.write(["escape"])
time.sleep(1.0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [7], in <cell line: 9>()
#       6 # 경로를 .py파일의 실행경로로 이동, 현재 경로로 이동
#       7 os.chdir(os.path.dirname(os.path.abspath('autokakao.ipynb')))
# ----> 9 picPosition = pyautogui.locateOnScreen('1.png')
#      10 print(picPosition)
#      12 if picPosition is None:
#
# File ~\anaconda3\lib\site-packages\pyautogui\__init__.py:175, in raisePyAutoGUIImageNotFoundException.<locals>.wrapper(*args, **kwargs)
#     172 @functools.wraps(wrappedFunction)
#     173 def wrapper(*args, **kwargs):
#     174     try:
# --> 175         return wrappedFunction(*args, **kwargs)
#     176     except pyscreeze.ImageNotFoundException:
#     177         raise ImageNotFoundException
#
# File ~\anaconda3\lib\site-packages\pyautogui\__init__.py:213, in locateOnScreen(*args, **kwargs)
#     211 @raisePyAutoGUIImageNotFoundException
#     212 def locateOnScreen(*args, **kwargs):
# --> 213     return pyscreeze.locateOnScreen(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pyscreeze\__init__.py:373, in locateOnScreen(image, minSearchTime, **kwargs)
#     371 try:
#     372     screenshotIm = screenshot(region=None) # the locateAll() function must handle cropping to return accurate coordinates, so don't pass a region here.
# --> 373     retVal = locate(image, screenshotIm, **kwargs)
#     374     try:
#     375         screenshotIm.fp.close()
#
# File ~\anaconda3\lib\site-packages\pyscreeze\__init__.py:353, in locate(needleImage, haystackImage, **kwargs)
#     351 # Note: The gymnastics in this function is because we want to make sure to exhaust the iterator so that the needle and haystack files are closed in locateAll.
#     352 kwargs['limit'] = 1
# --> 353 points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#     354 if len(points) > 0:
#     355     return points[0]
#
# File ~\anaconda3\lib\site-packages\pyscreeze\__init__.py:262, in _locateAll_python(needleImage, haystackImage, grayscale, limit, region, step, confidence)
#     259 needleFileObj = None
#     260 if isinstance(needleImage, (str, unicode)):
#     261     # 'image' is a filename, load the Image object
# --> 262     needleFileObj = open(needleImage, 'rb')
#     263     needleImage = Image.open(needleFileObj)
#     265 haystackFileObj = None
#
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-108:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-109:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-110:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-111:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-112:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-113:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-114:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-115:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-116:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-117:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-118:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-119:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-120:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-121:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-122:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-123:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Box(left=1526, top=102, width=153, height=64)
# None
# None
# Exception in thread Thread-125:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 23, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 582, in center
#     return Point(coords[0] + int(coords[2] / 2), coords[1] + int(coords[3] / 2))
# TypeError: 'NoneType' object is not subscriptable
# None
# None
# None
# None
# None
# None
# Exception in thread Thread-126:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 23, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 582, in center
#     return Point(coords[0] + int(coords[2] / 2), coords[1] + int(coords[3] / 2))
# TypeError: 'NoneType' object is not subscriptable
# Exception in thread Thread-127:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
# Box(left=1526, top=102, width=153, height=64)
# None
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 23, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 582, in center
#     return Point(coords[0] + int(coords[2] / 2), coords[1] + int(coords[3] / 2))
# TypeError: 'NoneType' object is not subscriptable
# None
# None
# Exception in thread Thread-129:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 23, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 582, in center
#     return Point(coords[0] + int(coords[2] / 2), coords[1] + int(coords[3] / 2))
# TypeError: 'NoneType' object is not subscriptable
# None
# None
# None
# Box(left=1525, top=100, width=158, height=69)
# None
# Exception in thread Thread-130:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 23, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 582, in center
#     return Point(coords[0] + int(coords[2] / 2), coords[1] + int(coords[3] / 2))
# TypeError: 'NoneType' object is not subscriptable
# None
# None
# None
# Exception in thread Thread-132:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 23, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 582, in center
#     return Point(coords[0] + int(coords[2] / 2), coords[1] + int(coords[3] / 2))
# TypeError: 'NoneType' object is not subscriptable
# None
# None
# None
# None
# Box(left=1526, top=102, width=153, height=64)
# Exception in thread Thread-133:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 23, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 582, in center
#     return Point(coords[0] + int(coords[2] / 2), coords[1] + int(coords[3] / 2))
# TypeError: 'NoneType' object is not subscriptable
# Box(left=1526, top=102, width=153, height=64)
# None
# None
# Exception in thread Thread-136:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 23, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 582, in center
#     return Point(coords[0] + int(coords[2] / 2), coords[1] + int(coords[3] / 2))
# TypeError: 'NoneType' object is not subscriptable
# None
# None
# None

# %%
import pyautogui
import pyperclip
import time
import threading
import os

os.chdir(os.path.dirname(os.path.abspath('autokakao.ipynb')))

def send():
    threading.Timer(10, send).start()
    
    picPosition = pyautogui.locateOnScreen('1.png')
    print(picPosition)
    
    if picPosition is None:
        picPosition = pyautogui.locateOnScreen('2.png')
        print(picPosition)
    
    if picPosition is None:
        picPosition = pyautogui.locateOnScreen('3.png')
        print(picPosition)
    
    clickPosition = pyautogui.center(picPosition)
    pyautogui.doubleClick(clickPosition)
    
    pyperclip.copy("세번째 테스트 내이름 부르면 해위~")
    pyautogui.hotkey("ctrl", "v")
    time.sleep(1.0)
    
    pyautogui.write(["enter"])
    time.sleep(1.0)
    
    pyautogui.write(["escape"])
    time.sleep(1.0)

send()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [4], in <cell line: 36>()
#      33     pyautogui.write(["escape"])
#      34     time.sleep(1.0)
# ---> 36 send()
#
# Input In [4], in send()
#       9 def send():
#      10     threading.Timer(10, send).start()
# ---> 12     picPosition = pyautogui.locateOnScreen('1.png')
#      13     print(picPosition)
#      15     if picPosition is None:
#
# File ~\anaconda3\lib\site-packages\pyautogui\__init__.py:175, in raisePyAutoGUIImageNotFoundException.<locals>.wrapper(*args, **kwargs)
#     172 @functools.wraps(wrappedFunction)
#     173 def wrapper(*args, **kwargs):
#     174     try:
# --> 175         return wrappedFunction(*args, **kwargs)
#     176     except pyscreeze.ImageNotFoundException:
#     177         raise ImageNotFoundException
#
# File ~\anaconda3\lib\site-packages\pyautogui\__init__.py:213, in locateOnScreen(*args, **kwargs)
#     211 @raisePyAutoGUIImageNotFoundException
#     212 def locateOnScreen(*args, **kwargs):
# --> 213     return pyscreeze.locateOnScreen(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pyscreeze\__init__.py:373, in locateOnScreen(image, minSearchTime, **kwargs)
#     371 try:
#     372     screenshotIm = screenshot(region=None) # the locateAll() function must handle cropping to return accurate coordinates, so don't pass a region here.
# --> 373     retVal = locate(image, screenshotIm, **kwargs)
#     374     try:
#     375         screenshotIm.fp.close()
#
# File ~\anaconda3\lib\site-packages\pyscreeze\__init__.py:353, in locate(needleImage, haystackImage, **kwargs)
#     351 # Note: The gymnastics in this function is because we want to make sure to exhaust the iterator so that the needle and haystack files are closed in locateAll.
#     352 kwargs['limit'] = 1
# --> 353 points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#     354 if len(points) > 0:
#     355     return points[0]
#
# File ~\anaconda3\lib\site-packages\pyscreeze\__init__.py:262, in _locateAll_python(needleImage, haystackImage, grayscale, limit, region, step, confidence)
#     259 needleFileObj = None
#     260 if isinstance(needleImage, (str, unicode)):
#     261     # 'image' is a filename, load the Image object
# --> 262     needleFileObj = open(needleImage, 'rb')
#     263     needleImage = Image.open(needleFileObj)
#     265 haystackFileObj = None
#
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-35:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-36:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-37:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-38:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-39:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-40:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-41:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-42:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-43:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-44:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-45:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-46:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-47:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-48:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-49:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-50:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-51:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-52:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-53:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-54:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-55:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-56:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-57:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-58:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-59:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-60:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'
# Exception in thread Thread-61:
# Traceback (most recent call last):
#   File "C:\Users\user\anaconda3\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\user\anaconda3\lib\threading.py", line 1299, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_9648\4207577363.py", line 12, in send
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 175, in wrapper
#     return wrappedFunction(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyautogui\__init__.py", line 213, in locateOnScreen
#     return pyscreeze.locateOnScreen(*args, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 373, in locateOnScreen
#     retVal = locate(image, screenshotIm, **kwargs)
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 353, in locate
#     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#   File "C:\Users\user\anaconda3\lib\site-packages\pyscreeze\__init__.py", line 262, in _locateAll_python
#     needleFileObj = open(needleImage, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '1.png'

# %%
# fps 핵 만들기
# https://simritest.com/reaction/
import pyautogui
import pyperclip
import time
import os

# 경로를 .py파일의 실행경로로 이동, 현재 경로로 이동
os.chdir(os.path.dirname(os.path.abspath('autokakao.ipynb')))

n = 0
while(n<5):
    # 모니터 기준 사진 좌표, 가로길이 세로길이를 찍어준다.
    # 픽셀수가 적고, 단색의 이미지일수록 더 빠르다.
    # 모니터 기준 사진 좌표, 가로길이 세로길이를 찍어준다.
    picPosition = pyautogui.locateOnScreen('click1.png')
    print(picPosition)
    if picPosition != None:
        # 마우스를 이동시켜준다(picPosition.left는 좌우, top은 상하)
        # 사진 기준으로 0,0으로 이동
        # 사진이 없으면 좌표를 못찾아서 오류가 난다.
        pyautogui.moveTo(picPosition.left, picPosition.top)
        
        # 클릭한다. default 값은 좌클릭
        # pyautogui.click()
        pyautogui.click()
        n += 1
# Out:
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [4], in <cell line: 14>()
#      11 print(picPosition)
#      13 # 사진의 좌표를 찍어주고 좌표값은 모니터 기준
# ---> 14 picPosition.left
#      16 # 마우스를 이동시켜준다
#      17 # 사진 기준으로 0,0으로 이동
#      18 pyautogui.moveTo(picPosition.left, picPosition.top)
#
# AttributeError: 'NoneType' object has no attribute 'left'

# %%
# fps 핵 만들기
# https://simritest.com/reaction/
import pyautogui
import pyperclip
import time
import os

# 경로를 .py파일의 실행경로로 이동, 현재 경로로 이동
os.chdir(os.path.dirname(os.path.abspath('autokakao.ipynb')))

n = 0
while(n<5):
    picPosition = pyautogui.locateOnScreen('click1.png')
    print(picPosition)
    if picPosition != None:
        pyautogui.click(picPosition.left, picPosition.top)
        n += 1
# Out:
# None
# None
# None
# Box(left=1018, top=301, width=7, height=7)
# None
# None
# None
# None
# None
# Box(left=1018, top=301, width=7, height=7)
# None
# None
# None
# None
# None
# None
# Box(left=1018, top=301, width=7, height=7)
# None
# None
# None
# None
# None
# None
# Box(left=1018, top=301, width=7, height=7)
# None
# None
# None
# None
# None
# None
# None
# Box(left=1018, top=301, width=7, height=7)
