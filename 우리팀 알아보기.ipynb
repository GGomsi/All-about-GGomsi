# %%
# webengine을 사용하기위해 따로 설치가 필요하다.
# !pip install PyQtWebEngine

# %%
from PyQt5 import QtWebEngineWidgets
from PyQt5 import QtCore, QtGui, QtWidgets

#class가 object를 상속받는 이유
#파이썬 2 (정확히는 2.2 이상) 에서는 클래스에 object를 명시적으로 상속시켜 줘야 비로소 우리가 파이썬 3에서 흔히 쓰는 클래스가 된다.
#파이썬 3 코드에서 굳이 object를 상속시켜 주는 이유는 대개 파이썬 2와의 호환성 혹은 작성 취향 때문이다.
class Ui_Dialog(object):
    def setupUi(self, Dialog):
        # 제목,사이즈 설정
        Dialog.setObjectName("Dialog")
        Dialog.resize(1206, 578)
        self.btn_4 = QtWidgets.QPushButton(Dialog)
        self.btn_4.setGeometry(QtCore.QRect(1010, 380, 191, 71))
        font = QtGui.QFont()
        font.setFamily("KoPub돋움체 Bold")
        font.setPointSize(14)
        self.btn_4.setFont(font)
        self.btn_4.setObjectName("btn_4")
        self.btn_2 = QtWidgets.QPushButton(Dialog)
        self.btn_2.setGeometry(QtCore.QRect(1010, 280, 191, 71))
        font = QtGui.QFont()
        font.setFamily("KoPub돋움체 Bold")
        font.setPointSize(14)
        self.btn_2.setFont(font)
        self.btn_2.setObjectName("btn_2")
        self.btn_3 = QtWidgets.QPushButton(Dialog)
        self.btn_3.setGeometry(QtCore.QRect(800, 380, 191, 71))
        font = QtGui.QFont()
        font.setFamily("KoPub돋움체 Bold")
        font.setPointSize(14)
        self.btn_3.setFont(font)
        self.btn_3.setObjectName("btn_3")
        self.btn_5 = QtWidgets.QPushButton(Dialog)
        self.btn_5.setGeometry(QtCore.QRect(800, 480, 191, 71))
        font = QtGui.QFont()
        font.setFamily("KoPub돋움체 Bold")
        font.setPointSize(14)
        self.btn_5.setFont(font)
        self.btn_5.setObjectName("btn_5")
        self.btn_6 = QtWidgets.QPushButton(Dialog)
        self.btn_6.setGeometry(QtCore.QRect(1010, 480, 191, 71))
        font = QtGui.QFont()
        font.setFamily("KoPub돋움체 Bold")
        font.setPointSize(14)
        self.btn_6.setFont(font)
        self.btn_6.setObjectName("btn_6")
        self.btn_1 = QtWidgets.QPushButton(Dialog)
        self.btn_1.setGeometry(QtCore.QRect(800, 280, 191, 71))
        font = QtGui.QFont()
        font.setFamily("KoPub돋움체 Bold")
        font.setPointSize(14)
        self.btn_1.setFont(font)
        self.btn_1.setObjectName("btn_1")
        self.comboBox = QtWidgets.QComboBox(Dialog)
        self.comboBox.setGeometry(QtCore.QRect(870, 210, 241, 41))
        self.comboBox.setObjectName("comboBox")
#         self.comboBox.additems(['jsuhak@naver.com','yang@naver.com','song@naver.com'])
        self.comboBox.addItem("email")
        self.comboBox.addItem("phone")
        self.comboBox.addItem("food")
#         self.textEdit = Qtwidgets.QTextEdit(Dialog)
#         self.textEdit.setGeometry(QtCore.QRect(810, 20, 371, 171))
#         self.textEdit.setObjectName("textEdit")
        self.lineEdit = QtWidgets.QLineEdit(Dialog)
        self.lineEdit.setGeometry(QtCore.QRect(810, 20, 371, 171))
        self.lineEdit.setObjectName("lineEdit")
        self.webEngineView = QtWebEngineWidgets.QWebEngineView(Dialog)
        self.webEngineView.setGeometry(QtCore.QRect(0, 0, 791, 581))
        self.webEngineView.setUrl(QtCore.QUrl("https://www.google.com/?gws_rd=ssl"))
        self.webEngineView.setObjectName("webEngineView")

        self.retranslateUi(Dialog)
        QtCore.QMetaObject.connectSlotsByName(Dialog)
        
        self.btn_1.clicked.connect(self.action_del)
        self.btn_2.clicked.connect(self.song)
        self.btn_3.clicked.connect(self.jung)
        self.btn_4.clicked.connect(self.park)
        self.btn_5.clicked.connect(self.yang)
        self.btn_6.clicked.connect(self.ggomsi)

    def retranslateUi(self, Dialog):
        _translate = QtCore.QCoreApplication.translate
        Dialog.setWindowTitle(_translate("Dialog", "Dialog"))
        self.btn_4.setText(_translate("Dialog", "박세호"))
        self.btn_2.setText(_translate("Dialog", "송하율"))
        self.btn_3.setText(_translate("Dialog", "정준수"))
        self.btn_5.setText(_translate("Dialog", "양정준"))
        self.btn_6.setText(_translate("Dialog", "주종일"))
        self.btn_1.setText(_translate("Dialog", "지우기"))
        self.comboBox.setItemText(0, _translate("Dialog", "이메일"))
        self.comboBox.setItemText(1, _translate("Dialog", "전화번호"))
        self.comboBox.setItemText(2, _translate("Dialog", "좋아하는 음식"))


    def action_del(self):
#         exist_text = self.textEdit.text()
        exist_text = self.lineEdit.text()
#         self.textEdit.setText(exist_text[:-1])
        self.lineEdit.setText(exist_text[-1:])
    
    def song(self):
        # lineEdit.text()는 현재 라인 에디트에 들어간거임.
#         text = self.textEdit.text()
        text = self.lineEdit.text()
        one_text = self.comboBox.currentText()
        if(one_text == "이메일"):
            # lineEdit은 한줄짜리라서 \n이 먹히질 않는다 이걸 해결하려면 textEdit으로 바꿔야됨!
#             self.textEdit.setText(test + "lucy12023@naver.com\n")
            self.lineEdit.setText(text + "lucy12023@naver.com\n")
        elif(one_text == "전화번호"):
#             self.textEdit.setText(text + "010-4624-1264")
            self.lineEdit.setText(text + "010-4624-1264")
        else: 
#             self.textEdit.setText(text + "초밥")
            self.lineEdit.setText(text + "초밥")
        
    def jung(self):
        text = self.lineEdit.text()
        one_text = self.comboBox.currentText()
        if(one_text == "이메일"):
            self.lineEdit.setText(text + "jim9622@naver.com")
        elif(one_text == "전화번호"):
            self.lineEdit.setText(text + "010-9622-3679")
        else: self.lineEdit.setText(text + "고구마치즈왕돈까스")
    
    def park(self):
        text = self.lineEdit.text()
        one_text = self.comboBox.currentText()
        if(one_text == "이메일"):
            self.lineEdit.setText(text + "rueiw5214@gmail.com")
        elif(one_text == "전화번호"):
            self.lineEdit.setText(text + "010-9809-9245")
        else: self.lineEdit.setText(text + "햄버거")
    
    def yang(self):
        text = self.lineEdit.text()
        one_text = self.comboBox.currentText()
        if(one_text == "이메일"):
            self.lineEdit.setText(text + "ost342@naver.com")
        elif(one_text == "전화번호"):
            self.lineEdit.setText(text + "010-7476-0285")
        else: self.lineEdit.setText(text + "김치볶음밥")
    
    def ggomsi(self):
        text = self.lineEdit.text()
        one_text = self.comboBox.currentText()
        if(one_text == "이메일"):
            self.lineEdit.setText(text + "jsuhak@naver.com")
        elif(one_text == "전화번호"):
            self.lineEdit.setText(text + "010-7740-1511")
        else: self.lineEdit.setText(text + "돈까스")
    

if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Dialog = QtWidgets.QDialog()
    ui = Ui_Dialog()
    ui.setupUi(Dialog)
    Dialog.show()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3377: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
